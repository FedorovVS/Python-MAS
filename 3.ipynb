# %% [markdown]
# # 3 Pandas + Seaborn
# Теперь то, что приходилось делать руками, попробуем делать проще и приятнее. Pandas - библиотека для работы с данными, прошаренный эксель. Seaborn отвечает за визуализацию. Ограниченный набор сложных вещей он делает проще и дружелюбнее (хотя мы скорее всего сразу не почувствуем разницы с обычным matplotlib).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv('6 class csv.csv')
data.head()
data['Luminosity(L/Lo)'].mean()
data[data['Star color']=='Red']
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                  16.120
# 1               3042          0.000500        0.1542                  16.600
# 2               2600          0.000300        0.1020                  18.700
# 3               2800          0.000200        0.1600                  16.650
# 4               1939          0.000138        0.1030                  20.060
# ..               ...               ...           ...                     ...
# 195             3598          0.002700        0.6700                  13.667
# 196             3142          0.001320        0.2580                  14.120
# 197             3496          0.001250        0.3360                  14.940
# 198             3324          0.006500        0.4710                  12.780
# 199             3463          0.002700        0.6750                  14.776
#
#      Star type Star color Spectral Class
# ...

# %% [markdown]
# Ещё методы для самостоятельного изучения (ключевое слово - Pandas DataFrame):
# describe
# value_counts
# groupby
# apply
# count
# drop
# Для сильных: [доки](https://pandas.pydata.org/docs/user_guide/index.html#user-guide)
# Для слабых: [хабр](https://habr.com/ru/company/ruvds/blog/494720/)
# ### Seaborn
# Страшный, но красивый пример:

# %%
sns.set_theme(style="whitegrid")

# Load the example planets dataset
planets = sns.load_dataset("planets")

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
g = sns.relplot(
    data=planets,
    x="distance", y="orbital_period",
    hue="year", size="mass",
    palette=cmap, sizes=(10, 200),
)
g.set(xscale="log", yscale="log")
g.ax.xaxis.grid(True, "minor", linewidth=.25)
g.ax.yaxis.grid(True, "minor", linewidth=.25)
g.despine(left=True, bottom=True)

# %% [markdown]
# Для ознакомления:
# scatterplot
# lineplot
# barplot
# countplot
# histplot
# ### Задание
# Используйте датасет 6 class csv.csv. Постройте диаграмму ГР так красиво, как получится (с цветом, размером). Предварительно подготовьте данные: проверьте на неполные строки, выбросите ненужные столбцы.
